# %% [markdown]
# # Notebook 0: A Naturalist's Field Notebook in Python
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/williamedwardhahn/birdsong/blob/main/Notebook_0_Python_Basics.ipynb)
#
# ---
#
# ## A Note Before We Begin
#
# What you're about to do — use a computer to listen to birdsong and find patterns in it — sits at the intersection of ideas that took centuries to develop. Fourier figured out that any complex sound can be broken into simple waves in the 1800s. Shannon formalized how to turn sound into numbers in 1948. Neural networks were sketched out in the 1940s, forgotten, rediscovered, and only became practical in the last decade. None of these people worked alone. Each one stood on the shoulders of the people who came before them, and now you're standing on all of theirs.
#
# **The goal here is not to memorize anything.** The real test of understanding is whether you can *play with the thing* — change it, break it, and see what happens. That's exactly what these notebooks are for. You won't be writing code from scratch — you'll be running it, reading it, tweaking things, and watching what happens.
#
# Some parts will click immediately. Others won't — and that's fine, you can always come back. The tools here are the same ones used in real research labs studying animal communication, conservation, and ecology. The gap between where you are now and real, useful science is smaller than you think. Explore the areas that excite you. That curiosity is the whole engine of science.
#
# ---

# %% [markdown]
# Imagine you're a field naturalist heading out at dawn to study birds. You carry a notebook to record what you see and hear — species names, song counts, times, locations.
#
# This notebook teaches you Python by doing exactly that: keeping a digital field journal about birds. By the end, you'll know how to store observations, organize data, do calculations, and make charts — the same skills used in the later birdsong analysis notebooks.
#
# **No programming experience needed.** Just run each cell from top to bottom.
#
# ## Before You Start
#
# **Save your own copy first!** The version you're looking at is read-only.
#
# 1. Go to **File → Save a copy in Drive**
# 2. Rename it with your name (e.g. `YourName_Notebook_0.ipynb`)
# 3. Work in **your copy** from now on — that's where your changes get saved
#
# **Colab tip:** The free version of Google Colab only lets you run **one or two notebooks at a time**. When you're done with this notebook, close it before opening the next one. If Colab disconnects or feels slow, go to **Runtime → Disconnect and delete runtime**, then reopen the notebook you want to work on.
#
# ## How to Run Code
#
# Each gray box below is a "code cell." To run it:
# - Click the **Play** button on the left side of the cell, **or**
# - Press **Shift + Enter** on your keyboard
#
# The result appears right below the cell. Try it now with the first one!

# %% [markdown]
# ---
# ## 1. Counting Birds — Python as a Calculator
#
# The simplest thing Python can do is math. Imagine you're tallying birds at a feeder:

# %%
# How many cardinals and sparrows at the feeder?
3 + 5

# %%
# A flock of 12 zebra finches visited 4 times today
12 * 4

# %%
# You recorded 45 songs over 3 hours — what's the average per hour?
45 / 3

# %%
# If a bird population doubles every year, how many after 8 years starting from 1?
# The ** symbol means "raised to the power of"
2 ** 8

# %%
# Python can handle absurdly big numbers — try 2 to the power of 100
2 ** 100

# %% [markdown]
# ---
# ## 2. Field Notes — Storing Information in Variables
#
# A naturalist labels their observations. In Python, we use **variables** — names that store values so we can refer to them later. Think of sticking a label on a specimen jar.

# %%
# Record this morning's observations
species = "Northern Cardinal"
songs_recorded = 9
observation_hours = 2.5

# Calculate songs per hour
songs_per_hour = songs_recorded / observation_hours

# Display the result
print(songs_per_hour)

# %% [markdown]
# The `print()` command displays a value on screen. You can include text alongside your numbers using **f-strings** — they start with `f` and let you drop variables inside `{curly braces}`:

# %%
print(f"Species: {species}")
print(f"Songs recorded: {songs_recorded}")
print(f"Songs per hour: {songs_per_hour}")

# %% [markdown]
# ---
# ## 3. Species Log — Working with Text
#
# Text in Python is called a **string**. It goes inside quotes. You can do useful things with strings — measure their length, change their case, or combine them.

# %%
common_name = "Song Sparrow"
latin_name = "Melospiza melodia"

# Combine text
full_entry = common_name + " (" + latin_name + ")"
print(full_entry)

# How long is the name?
print(f"Common name has {len(common_name)} characters.")

# Convert to uppercase (like a field notebook heading)
print(common_name.upper())

# %% [markdown]
# ---
# ## 4. Species Checklist — Lists
#
# A **list** holds multiple items in order — like a checklist of species you've spotted. Lists use square brackets `[]` with items separated by commas.

# %%
# Today's species checklist
checklist = ["Bachman's Sparrow", "Northern Cardinal", "Song Sparrow",
             "Swamp Sparrow", "Zebra Finch"]

print(f"Species observed today: {len(checklist)}")
print(f"First species spotted: {checklist[0]}")
print(f"Last species spotted:  {checklist[-1]}")

# %%
# A new bird appears! Add it to the checklist.
checklist.append("Eastern Bluebird")
print(f"Updated checklist ({len(checklist)} species):")
print(checklist)

# %% [markdown]
# You can also store numbers in lists — like how many songs you recorded from each species:

# %%
song_counts = [19, 9, 15, 10, 45]

print(f"Total songs recorded: {sum(song_counts)}")
print(f"Most songs from one species: {max(song_counts)}")
print(f"Fewest songs: {min(song_counts)}")

# %% [markdown]
# ---
# ## 5. Walking the Trail — Loops
#
# A **loop** repeats an action for each item in a list — like walking a trail and noting every bird you hear. The `for` keyword does this:

# %%
# Print a formatted field log entry for each species
species_list = ["Bachman's Sparrow", "Northern Cardinal", "Song Sparrow",
                "Swamp Sparrow", "Zebra Finch"]
song_counts  = [19, 9, 15, 10, 45]

print("=" * 40)
print("  FIELD LOG — Song Counts")
print("=" * 40)

for i in range(len(species_list)):
    name = species_list[i]
    count = song_counts[i]
    print(f"  {name:.<25} {count} songs")

print("=" * 40)
print(f"  Total: {sum(song_counts)} songs")

# %% [markdown]
# ---
# ## 6. The Naturalist's Toolkit — Dictionaries
#
# A **dictionary** pairs labels with values — like a field guide entry. It uses curly braces `{}` with `key: value` pairs.

# %%
# A field guide entry for one species
cardinal = {
    "common_name": "Northern Cardinal",
    "latin_name": "Cardinalis cardinalis",
    "songs_recorded": 9,
    "habitat": "woodland edges, gardens",
    "color": "red"
}

# Access a specific piece of information
print(f"Species: {cardinal['common_name']}")
print(f"Latin:   {cardinal['latin_name']}")
print(f"Habitat: {cardinal['habitat']}")
print(f"Songs:   {cardinal['songs_recorded']}")

# %% [markdown]
# ---
# ## 7. Reusable Tools — Functions
#
# A **function** is a reusable recipe. You define it once with `def`, then call it whenever you need it — like having a standard form you fill out for each bird.

# %%
def field_entry(species, songs, hours):
    """Print a formatted field observation entry."""
    rate = songs / hours
    print(f"--- {species} ---")
    print(f"    Songs: {songs}  |  Hours: {hours}  |  Rate: {rate:.1f} songs/hr")
    print()

# Use the function for each species
field_entry("Bachman's Sparrow", 19, 3.0)
field_entry("Northern Cardinal", 9, 2.5)
field_entry("Song Sparrow", 15, 2.0)
field_entry("Swamp Sparrow", 10, 1.5)
field_entry("Zebra Finch", 45, 4.0)

# %% [markdown]
# ---
# ## 8. Drawing What You See — Making Charts
#
# Naturalists sketch what they observe. In Python, we use the `matplotlib` library to draw charts. We also use `numpy` for working with numbers efficiently.
#
# We **import** these tools — think of it as grabbing a specific field guide off the shelf.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Bar chart: songs recorded per species
species_list = ["Bachman's\nSparrow", "Northern\nCardinal", "Song\nSparrow",
                "Swamp\nSparrow", "Zebra\nFinch"]
song_counts  = [19, 9, 15, 10, 45]

plt.figure(figsize=(8, 4))
plt.bar(species_list, song_counts, color=['#2ecc71', '#e74c3c', '#3498db', '#9b59b6', '#f39c12'])
plt.title("Songs Recorded Per Species")
plt.ylabel("Number of Songs")
plt.show()

# %% [markdown]
# ### What Does a Sound Wave Look Like?
#
# Bird songs are vibrations in the air. When we record them, we capture how the air pressure changes over time. Here's a simple wave — in the later notebooks, you'll see real birdsong waveforms that look much more complex.

# %%
# A simple tone (like a single pure whistle)
time = np.linspace(0, 0.01, 500)  # 10 milliseconds of time
frequency = 440  # 440 Hz = the note A
wave = np.sin(2 * np.pi * frequency * time)

plt.figure(figsize=(10, 3))
plt.plot(time * 1000, wave, color='#2ecc71')
plt.title("A Simple Sound Wave (440 Hz — the note A)")
plt.xlabel("Time (milliseconds)")
plt.ylabel("Air Pressure")
plt.grid(True, alpha=0.3)
plt.show()

print("Real birdsong is a complex mix of many frequencies at once!")

# %%
# Combine two tones — like a bird singing two notes at once
wave_low = np.sin(2 * np.pi * 300 * time)   # 300 Hz (low note)
wave_high = np.sin(2 * np.pi * 800 * time)  # 800 Hz (high note)
combined = wave_low + wave_high

fig, axes = plt.subplots(3, 1, figsize=(10, 6), sharex=True)

axes[0].plot(time * 1000, wave_low, color='#3498db')
axes[0].set_title("Low Note (300 Hz)")
axes[0].set_ylabel("Amplitude")

axes[1].plot(time * 1000, wave_high, color='#e74c3c')
axes[1].set_title("High Note (800 Hz)")
axes[1].set_ylabel("Amplitude")

axes[2].plot(time * 1000, combined, color='#9b59b6')
axes[2].set_title("Both Notes Combined")
axes[2].set_ylabel("Amplitude")
axes[2].set_xlabel("Time (milliseconds)")

plt.tight_layout()
plt.show()

print("A spectrogram (Notebook 1) shows us which frequencies are present at each moment.")

# %% [markdown]
# ### What Does REAL Birdsong Look Like?
#
# Those sine waves are neat and tidy. But real birdsong? It's wild. Let's load an actual bird recording and compare it to our simple tones.
#
# The next cell uses two new tricks:
# - Lines starting with `!` run **shell commands** — instructions for the computer itself, not Python. `!pip install` adds a new library, and `!git clone` downloads files from the internet.
# - `librosa` is a library for working with audio, just like `matplotlib` is for charts.

# %%
# !pip install -q librosa

import librosa
import os

# Download the birdsong dataset (same one used in later notebooks)
REPO_DIR = "/content/birdsong"
if not os.path.exists(REPO_DIR):
    # !git clone -q https://github.com/williamedwardhahn/birdsong.git {REPO_DIR}

# Load one real birdsong recording (a Zebra Finch)
# We filter for .wav files to avoid picking up any hidden files
zebra_finch_dir = os.path.join(REPO_DIR, "zebra_finch")
wav_files = sorted([f for f in os.listdir(zebra_finch_dir) if f.endswith('.wav')])
birdsong_file = os.path.join(zebra_finch_dir, wav_files[0])
bird_audio, bird_sr = librosa.load(birdsong_file, sr=None, duration=2)

# Create a pure sine wave at the same duration for comparison
bird_time = np.linspace(0, len(bird_audio) / bird_sr, len(bird_audio))
sine_wave = np.sin(2 * np.pi * 440 * bird_time)

# Plot them side by side
fig, axes = plt.subplots(2, 1, figsize=(10, 5))

axes[0].plot(bird_time, sine_wave, color='#2ecc71')
axes[0].set_title("Simple Sine Wave (440 Hz)")
axes[0].set_ylabel("Amplitude")

axes[1].plot(bird_time, bird_audio, color='#e74c3c')
axes[1].set_title("Real Birdsong (Zebra Finch)")
axes[1].set_ylabel("Amplitude")
axes[1].set_xlabel("Time (seconds)")

plt.tight_layout()
plt.show()

print("See the difference? The sine wave is perfectly regular.")
print("The birdsong is complex — full of rapid changes, harmonics, and structure.")
print("\nListen to the birdsong:")

# %%
from IPython.display import Audio, display
display(Audio(bird_audio, rate=bird_sr))

print("In the next notebook, we'll figure out what's hiding inside that complexity.")

# %% [markdown]
# ---
# ## 9. Conditions — Making Decisions
#
# Sometimes you need to make decisions based on your data. Python uses `if`, `elif` (else if), and `else` for this:

# %%
def classify_singer(song_count):
    """Classify a species by how many songs were recorded."""
    if song_count >= 30:
        return "Prolific singer"
    elif song_count >= 15:
        return "Moderate singer"
    else:
        return "Occasional singer"

# Test it with our data
birds  = ["Bachman's Sparrow", "Northern Cardinal", "Song Sparrow",
          "Swamp Sparrow", "Zebra Finch"]
counts = [19, 9, 15, 10, 45]

for bird, count in zip(birds, counts):
    category = classify_singer(count)
    print(f"{bird}: {count} songs -> {category}")

# %% [markdown]
# ---
# ## 10. Your Field Notebook
#
# Use the cell below as your own workspace. Some ideas to try:
#
# - Add a new species to the checklist
# - Change the song counts and re-run the bar chart
# - Write a function that takes a species name and prints a fun fact
# - Make a pie chart (`plt.pie(...)`) of the song counts
#
# **You can't break anything** — if something goes wrong, just edit and re-run!

# %%
# Your field notebook — experiment here!

# %% [markdown]
# ---
#
# ## What You Learned
#
# | Concept | What it does | Naturalist analogy |
# |---------|-------------|--------------------|
# | **Variables** | Store values | Labeling a specimen jar |
# | **Strings** | Work with text | Writing species names |
# | **Lists** | Hold multiple items | A species checklist |
# | **Dictionaries** | Pair labels with values | A field guide entry |
# | **Loops** | Repeat actions | Walking a trail, noting each bird |
# | **Functions** | Reusable code blocks | A standard observation form |
# | **Conditions** | Make decisions | Classifying by behavior |
# | **Libraries** | Pre-built tools | Grabbing a field guide off the shelf |
# | **Charts** | Visualize data | Sketching what you observe |
#
# **Next step:** Open **Notebook 1 — Sound as Data** to discover what's hiding inside birdsong!
